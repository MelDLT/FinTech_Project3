# %%
import numpy as np
import pandas as pd
#import hvplot.pandas
import ccxt
import os

# %%
kraken_public_key = os.getenv('KRAKEN_PUBLIC_KEY')
kraken_secret_key = os.getenv('KRAKEN_SECRET_KEY')

# %%
exchange = ccxt.kraken({
    'apiKey': kraken_public_key,
    'secret': kraken_secret_key,
})

# %%
def get_crypto_details ()
   crypto_details = exchange.load_markets()

# Import data as a Pandas DataFrame
   crypto_df = pd.DataFrame(crypto_details)
return crypto_df
# Out:
#                                                       ADA/ETH  \
# active                                                   True
# altname                                                ADAETH
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAETH
# info        {'altname': 'ADAETH', 'wsname': 'ADA/ETH', 'ac...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 7}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                                ADA/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/EUR  \
# active                                                   True
# altname                                                ADAEUR
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAEUR
# info        {'altname': 'ADAEUR', 'wsname': 'ADA/EUR', 'ac...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                ADA/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/USD  \
# active                                                   True
# altname                                                ADAUSD
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAUSD
# info        {'altname': 'ADAUSD', 'wsname': 'ADA/USD', 'ac...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                ADA/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ADA/BTC  \
# active                                                   True
# altname                                                ADAXBT
# base                                                      ADA
# baseId                                                    ADA
# darkpool                                                False
# id                                                     ADAXBT
# info        {'altname': 'ADAXBT', 'wsname': 'ADA/XBT', 'ac...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 8}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                                ADA/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/ETH  \
# active                                                   True
# altname                                               ALGOETH
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOETH
# info        {'altname': 'ALGOETH', 'wsname': 'ALGO/ETH', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 7}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                               ALGO/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/EUR  \
# active                                                   True
# altname                                               ALGOEUR
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOEUR
# info        {'altname': 'ALGOEUR', 'wsname': 'ALGO/EUR', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                               ALGO/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/USD  \
# active                                                   True
# altname                                               ALGOUSD
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOUSD
# info        {'altname': 'ALGOUSD', 'wsname': 'ALGO/USD', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                               ALGO/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ALGO/BTC  \
# active                                                   True
# altname                                               ALGOXBT
# base                                                     ALGO
# baseId                                                   ALGO
# darkpool                                                False
# id                                                    ALGOXBT
# info        {'altname': 'ALGOXBT', 'wsname': 'ALGO/XBT', '...
# limits      {'amount': {'min': 50.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 8}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                               ALGO/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ATOM/ETH  \
# active                                                   True
# altname                                               ATOMETH
# base                                                     ATOM
# baseId                                                   ATOM
# darkpool                                                False
# id                                                    ATOMETH
# info        {'altname': 'ATOMETH', 'wsname': 'ATOM/ETH', '...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 6}
# quote                                                     ETH
# quoteId                                                  XETH
# symbol                                               ATOM/ETH
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                      ATOM/EUR  ...  \
# active                                                   True  ...
# altname                                               ATOMEUR  ...
# base                                                     ATOM  ...
# baseId                                                   ATOM  ...
# darkpool                                                False  ...
# id                                                    ATOMEUR  ...
# info        {'altname': 'ATOMEUR', 'wsname': 'ATOM/EUR', '...  ...
# limits      {'amount': {'min': 1.0, 'max': 100000000.0}, '...  ...
# maker                                                  0.0016  ...
# percentage                                               True  ...
# precision                           {'amount': 8, 'price': 4}  ...
# quote                                                     EUR  ...
# quoteId                                                  ZEUR  ...
# symbol                                               ATOM/EUR  ...
# taker                                                  0.0026  ...
# tierBased                                                True  ...
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...  ...
#
#                                                       XRP/EUR  \
# active                                                   True
# altname                                                XRPEUR
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZEUR
# info        {'altname': 'XRPEUR', 'wsname': 'XRP/EUR', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                XRP/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       XRP/JPY  \
# active                                                   True
# altname                                                XRPJPY
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZJPY
# info        {'altname': 'XRPJPY', 'wsname': 'XRP/JPY', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     JPY
# quoteId                                                  ZJPY
# symbol                                                XRP/JPY
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       XRP/USD  \
# active                                                   True
# altname                                                XRPUSD
# base                                                      XRP
# baseId                                                   XXRP
# darkpool                                                False
# id                                                   XXRPZUSD
# info        {'altname': 'XRPUSD', 'wsname': 'XRP/USD', 'ac...
# limits      {'amount': {'min': 30.0, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                XRP/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/BTC  \
# active                                                   True
# altname                                                ZECXBT
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECXXBT
# info        {'altname': 'ZECXBT', 'wsname': 'ZEC/XBT', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     BTC
# quoteId                                                  XXBT
# symbol                                                ZEC/BTC
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/EUR  \
# active                                                   True
# altname                                                ZECEUR
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECZEUR
# info        {'altname': 'ZECEUR', 'wsname': 'ZEC/EUR', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     EUR
# quoteId                                                  ZEUR
# symbol                                                ZEC/EUR
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       ZEC/USD  \
# active                                                   True
# altname                                                ZECUSD
# base                                                      ZEC
# baseId                                                   XZEC
# darkpool                                                False
# id                                                   XZECZUSD
# info        {'altname': 'ZECUSD', 'wsname': 'ZEC/USD', 'ac...
# limits      {'amount': {'min': 0.03, 'max': 100000000.0}, ...
# maker                                                  0.0016
# percentage                                               True
# precision                           {'amount': 8, 'price': 2}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                ZEC/USD
# taker                                                  0.0026
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       EUR/USD  \
# active                                                   True
# altname                                                EURUSD
# base                                                      EUR
# baseId                                                   ZEUR
# darkpool                                                False
# id                                                   ZEURZUSD
# info        {'altname': 'EURUSD', 'wsname': 'EUR/USD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                EUR/USD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       GBP/USD  \
# active                                                   True
# altname                                                GBPUSD
# base                                                      GBP
# baseId                                                   ZGBP
# darkpool                                                False
# id                                                   ZGBPZUSD
# info        {'altname': 'GBPUSD', 'wsname': 'GBP/USD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     USD
# quoteId                                                  ZUSD
# symbol                                                GBP/USD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       USD/CAD  \
# active                                                   True
# altname                                                USDCAD
# base                                                      USD
# baseId                                                   ZUSD
# darkpool                                                False
# id                                                   ZUSDZCAD
# info        {'altname': 'USDCAD', 'wsname': 'USD/CAD', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 5}
# quote                                                     CAD
# quoteId                                                  ZCAD
# symbol                                                USD/CAD
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
#                                                       USD/JPY
# active                                                   True
# altname                                                USDJPY
# base                                                      USD
# baseId                                                   ZUSD
# darkpool                                                False
# id                                                   ZUSDZJPY
# info        {'altname': 'USDJPY', 'wsname': 'USD/JPY', 'ac...
# limits      {'amount': {'min': 10.0, 'max': 100000000.0}, ...
# maker                                                   0.002
# percentage                                               True
# precision                           {'amount': 8, 'price': 3}
# quote                                                     JPY
# quoteId                                                  ZJPY
# symbol                                                USD/JPY
# taker                                                   0.002
# tierBased                                                True
# tiers       {'taker': [[0, 0.0026], [50000, 0.0024], [1000...
#
# [17 rows x 203 columns]

# %%
#print(type(crypto_df.columns.values))
#print(crypto_df.columns.values)
#print(len(crypto_df.columns.values))
# Out:
# <class 'numpy.ndarray'>
# ['ADA/ETH' 'ADA/EUR' 'ADA/USD' 'ADA/BTC' 'ALGO/ETH' 'ALGO/EUR' 'ALGO/USD'
#  'ALGO/BTC' 'ATOM/ETH' 'ATOM/EUR' 'ATOM/USD' 'ATOM/BTC' 'AUD/JPY'
#  'AUD/USD' 'BAT/ETH' 'BAT/EUR' 'BAT/USD' 'BAT/BTC' 'BCH/AUD' 'BCH/ETH'
#  'BCH/EUR' 'BCH/GBP' 'BCH/USD' 'BCH/USDT' 'BCH/BTC' 'COMP/ETH' 'COMP/EUR'
#  'COMP/USD' 'COMP/BTC' 'DAI/EUR' 'DAI/USD' 'DAI/USDT' 'DASH/EUR'
#  'DASH/USD' 'DASH/BTC' 'DOT/ETH' 'DOT/EUR' 'DOT/USD' 'DOT/BTC' 'EOS/ETH'
#  'EOS/EUR' 'EOS/USD' 'EOS/BTC' 'ETH/AUD' 'ETH/CHF' 'ETH/DAI' 'ETH/USDC'
#  'ETH/USDT' 'EUR/AUD' 'EUR/CAD' 'EUR/CHF' 'EUR/GBP' 'EUR/JPY' 'GNO/ETH'
#  'GNO/EUR' 'GNO/USD' 'GNO/BTC' 'ICX/ETH' 'ICX/EUR' 'ICX/USD' 'ICX/BTC'
#  'KAVA/ETH' 'KAVA/EUR' 'KAVA/USD' 'KAVA/BTC' 'KNC/ETH' 'KNC/EUR' 'KNC/USD'
#  'KNC/BTC' 'LINK/ETH' 'LINK/EUR' 'LINK/USD' 'LINK/BTC' 'LSK/ETH' 'LSK/EUR'
#  'LSK/USD' 'LSK/BTC' 'LTC/AUD' 'LTC/ETH' 'LTC/GBP' 'LTC/USDT' 'NANO/ETH'
#  'NANO/EUR' 'NANO/USD' 'NANO/BTC' 'OMG/ETH' 'OMG/EUR' 'OMG/USD' 'OMG/BTC'
#  'OXT/ETH' 'OXT/EUR' 'OXT/USD' 'OXT/BTC' 'PAXG/ETH' 'PAXG/EUR' 'PAXG/USD'
#  'PAXG/BTC' 'QTUM/ETH' 'QTUM/EUR' 'QTUM/USD' 'QTUM/BTC' 'REPV2/ETH'
#  'REPV2/EUR' 'REPV2/USD' 'REPV2/BTC' 'SC/ETH' 'SC/EUR' 'SC/USD' 'SC/BTC'
#  'STORJ/ETH' 'STORJ/EUR' 'STORJ/USD' 'STORJ/BTC' 'TRX/ETH' 'TRX/EUR'
#  'TRX/USD' 'TRX/BTC' 'USDC/EUR' 'USD/CHF' 'USDC/USD' 'USDC/USDT'
#  'USDT/AUD' 'USDT/CAD' 'USDT/CHF' 'USDT/EUR' 'USDT/GBP' 'USDT/JPY'
#  'USDT/USD' 'WAVES/ETH' 'WAVES/EUR' 'WAVES/USD' 'WAVES/BTC' 'BTC/AUD'
#  'BTC/CHF' 'BTC/DAI' 'BTC/USDC' 'BTC/USDT' 'DOGE/EUR' 'DOGE/USD' 'ETC/ETH'
#  'ETC/BTC' 'ETC/EUR' 'ETC/USD' 'ETH/BTC' 'ETHXBT.d' 'ETH/CAD' 'ETHCAD.d'
#  'ETH/EUR' 'ETHEUR.d' 'ETH/GBP' 'ETHGBP.d' 'ETH/JPY' 'ETHJPY.d' 'ETH/USD'
#  'ETHUSD.d' 'LTC/BTC' 'LTC/EUR' 'LTC/USD' 'MLN/ETH' 'MLN/BTC' 'MLN/EUR'
#  'MLN/USD' 'REP/ETH' 'REP/BTC' 'REP/EUR' 'REP/USD' 'XRP/AUD' 'XRP/ETH'
#  'XRP/GBP' 'XRP/USDT' 'XTZ/ETH' 'XTZ/EUR' 'XTZ/USD' 'XTZ/BTC' 'BTC/CAD'
#  'XBTCAD.d' 'BTC/EUR' 'XBTEUR.d' 'BTC/GBP' 'XBTGBP.d' 'BTC/JPY' 'XBTJPY.d'
#  'BTC/USD' 'XBTUSD.d' 'DOGE/BTC' 'XLM/BTC' 'XLM/EUR' 'XLM/USD' 'XMR/BTC'
#  'XMR/EUR' 'XMR/USD' 'XRP/BTC' 'XRP/CAD' 'XRP/EUR' 'XRP/JPY' 'XRP/USD'
#  'ZEC/BTC' 'ZEC/EUR' 'ZEC/USD' 'EUR/USD' 'GBP/USD' 'USD/CAD' 'USD/JPY']
# 203

# %%
#exchange.has
# Out:
# {'loadMarkets': True,
#  'cancelAllOrders': False,
#  'cancelOrder': True,
#  'cancelOrders': False,
#  'CORS': False,
#  'createDepositAddress': True,
#  'createLimitOrder': True,
#  'createMarketOrder': True,
#  'createOrder': True,
#  'deposit': False,
#  'editOrder': 'emulated',
#  'fetchBalance': True,
#  'fetchClosedOrders': True,
#  'fetchCurrencies': True,
#  'fetchDepositAddress': True,
#  'fetchDeposits': True,
#  'fetchL2OrderBook': True,
#  'fetchLedger': True,
#  'fetchMarkets': True,
#  'fetchMyTrades': True,
#  'fetchOHLCV': True,
#  'fetchOpenOrders': True,
#  'fetchOrder': True,
#  'fetchOrderBook': True,
#  'fetchOrderBooks': False,
#  'fetchOrders': False,
#  'fetchOrderTrades': 'emulated',
#  'fetchStatus': 'emulated',
#  'fetchTicker': True,
#  'fetchTickers': True,
#  'fetchTime': True,
#  'fetchTrades': True,
#  'fetchTradingFee': True,
#  'fetchTradingFees': True,
#  'fetchFundingFee': False,
#  'fetchFundingFees': False,
#  'fetchTradingLimits': False,
#  'fetchTransactions': False,
#  'fetchWithdrawals': True,
#  'privateAPI': True,
#  'publicAPI': True,
#  'signIn': False,
#  'withdraw': True,
#  'fetchLedgerEntry': True}

# %%
def get_crypto_data (exchange, ticker)
   historical_prices = exchange.fetch_ohlcv( ticker, "1d")

# Import the data as a Pandas DataFrame and set the columns
   historical_prices_df = pd.DataFrame(
   historical_prices, columns=["timestamp", "open", "high", "low", "close", "volume"]
)
   #historical_prices_df
# Out:
#          timestamp     open     high      low    close        volume
# 0    1535846400000   7191.3   7331.1   7127.5   7294.7   3383.464791
# 1    1535932800000   7294.5   7329.9   7183.5   7256.1   2119.023043
# 2    1536019200000   7256.1   7405.9   7219.2   7359.3   2791.506356
# 3    1536105600000   7359.3   7389.4   6638.8   6686.6   7620.246686
# 4    1536192000000   6684.4   6702.3   6250.0   6494.8   9576.541423
# 5    1536278400000   6494.8   6524.8   6318.8   6397.6   3234.923559
# 6    1536364800000   6397.6   6457.7   6073.9   6183.2   3870.776225
# 7    1536451200000   6183.2   6459.4   6137.6   6230.9   3636.570370
# 8    1536537600000   6230.9   6371.3   6230.9   6304.5   3377.333021
# 9    1536624000000   6304.5   6410.9   6162.4   6282.3   3534.805915
# 10   1536710400000   6282.3   6366.4   6195.0   6319.5   2968.878955
# 11   1536796800000   6319.5   6595.9   6319.5   6487.1   5151.303808
# 12   1536883200000   6490.5   6599.8   6388.0   6482.9   3924.513795
# 13   1536969600000   6482.9   6568.4   6465.2   6520.0   1288.637276
# 14   1537056000000   6520.0   6520.1   6342.8   6497.9   1576.255832
# 15   1537142400000   6497.9   6532.1   6202.2   6250.0   5043.656090
# 16   1537228800000   6250.0   6384.9   6225.0   6330.5   3230.501339
# 17   1537315200000   6330.7   6574.0   6102.6   6392.1   4727.049112
# 18   1537401600000   6392.1   6547.2   6339.2   6491.2   3686.019596
# 19   1537488000000   6491.2   6819.5   6480.0   6755.3   5723.723844
# 20   1537574400000   6755.3   6836.4   6625.1   6717.0   3104.851605
# 21   1537660800000   6717.0   6768.0   6660.1   6700.0   1383.163063
# 22   1537747200000   6700.2   6719.9   6545.0   6579.2   3763.199908
# 23   1537833600000   6579.2   6580.0   6318.5   6435.0   5070.277440
# 24   1537920000000   6434.9   6540.7   6372.0   6453.5   3234.757950
# 25   1538006400000   6452.0   6720.0   6430.9   6683.8   3350.658400
# 26   1538092800000   6683.7   6796.2   6529.4   6622.3   4449.791544
# 27   1538179200000   6622.3   6622.3   6450.1   6582.7   2152.339935
# 28   1538265600000   6582.2   6641.0   6518.0   6604.1   1020.607491
# 29   1538352000000   6603.8   6633.3   6490.2   6572.6   1863.850102
# ..             ...      ...      ...      ...      ...           ...
# 690  1595462400000   9529.9   9676.0   9460.0   9612.0   4068.270319
# 691  1595548800000   9612.0   9649.0   9480.0   9553.6   3345.553560
# 692  1595635200000   9553.6   9748.1   9540.9   9710.2   2412.074061
# 693  1595721600000   9710.2  10197.0   9666.7   9939.6   5224.800838
# 694  1595808000000   9939.6  11420.0   9937.1  11046.1  16317.134181
# 695  1595894400000  11046.1  11263.1  10588.0  10934.0   8489.685815
# 696  1595980800000  10934.0  11348.0  10852.2  11108.2   6258.410778
# 697  1596067200000  11108.2  11187.2  10828.8  11114.8   5060.251681
# 698  1596153600000  11114.8  11460.0  10980.0  11356.2   5391.832875
# 699  1596240000000  11356.2  11883.4  11239.4  11809.9   6935.588019
# 700  1596326400000  11809.9  12126.6  10590.0  11067.1   9103.232757
# 701  1596412800000  11072.1  11484.2  10827.9  11237.3   4379.576693
# 702  1596499200000  11237.1  11419.0  11028.5  11197.5   3286.910246
# 703  1596585600000  11197.5  11791.4  11099.2  11746.0   5230.820707
# 704  1596672000000  11746.0  11912.2  11579.3  11771.5   4417.042034
# 705  1596758400000  11771.5  11918.7  11350.0  11603.5   5264.973234
# 706  1596844800000  11603.5  11813.8  11540.0  11768.0   2217.988309
# 707  1596931200000  11768.0  11804.9  11532.5  11687.5   1618.552709
# 708  1597017600000  11687.5  12082.9  11535.5  11898.7   6928.454340
# 709  1597104000000  11898.7  11939.0  11133.0  11391.7   7265.366587
# 710  1597190400000  11391.7  11620.0  11163.0  11576.6   4049.321046
# 711  1597276800000  11576.6  11799.0  11269.0  11794.6   4296.453871
# 712  1597363200000  11794.8  11867.1  11658.5  11772.6   3549.573385
# 713  1597449600000  11772.6  11988.0  11675.0  11858.3   3176.274402
# 714  1597536000000  11858.3  11939.5  11701.0  11916.8   1955.262373
# 715  1597622400000  11916.8  12480.6  11775.0  12301.7   6151.272061
# 716  1597708800000  12301.7  12393.7  11807.7  11957.0   6055.424528
# 717  1597795200000  11957.0  12020.0  11569.4  11757.4   5945.744553
# 718  1597881600000  11757.4  11899.7  11675.0  11864.6   3273.143888
# 719  1597968000000  11864.5  11884.8  11861.8  11861.8     29.160570
#
# [720 rows x 6 columns]

# %%
historical_prices_df["date"] = pd.to_datetime(
    historical_prices_df["timestamp"], unit="ms"
)
historical_prices_df.tail()
# Out:
#          timestamp     open     high      low    close       volume       date
# 715  1597622400000  11916.8  12480.6  11775.0  12301.7  6151.272061 2020-08-17
# 716  1597708800000  12301.7  12393.7  11807.7  11957.0  6055.424528 2020-08-18
# 717  1597795200000  11957.0  12020.0  11569.4  11757.4  5945.744553 2020-08-19
# 718  1597881600000  11757.4  11899.7  11675.0  11864.6  3273.143888 2020-08-20
# 719  1597968000000  11864.5  11884.8  11861.8  11861.8    29.160570 2020-08-21

# %%
historical_prices_df.set_index("date", inplace= True)

#, infer_datetime_format=True, parse_dates=True, inplace=True, ascending=True)
#historical_prices_df.head()

#df2  index_col="Date", infer_datetime_format=True, parse_dates=True)['Close']
#df2 = df2.sort_index()
#df2.tail()

# %%
historical_prices_df.tail()
# Out:
#                 timestamp     open     high      low    close       volume
# date
# 2020-08-17  1597622400000  11916.8  12480.6  11775.0  12301.7  6151.272061
# 2020-08-18  1597708800000  12301.7  12393.7  11807.7  11957.0  6055.424528
# 2020-08-19  1597795200000  11957.0  12020.0  11569.4  11757.4  5945.744553
# 2020-08-20  1597881600000  11757.4  11899.7  11675.0  11864.6  3273.143888
# 2020-08-21  1597968000000  11864.5  11884.8  11861.8  11861.8    29.160570

# %%
historical_prices_df.head(10)
# Out:
#                 timestamp    open    high     low   close       volume
# date
# 2018-09-02  1535846400000  7191.3  7331.1  7127.5  7294.7  3383.464791
# 2018-09-03  1535932800000  7294.5  7329.9  7183.5  7256.1  2119.023043
# 2018-09-04  1536019200000  7256.1  7405.9  7219.2  7359.3  2791.506356
# 2018-09-05  1536105600000  7359.3  7389.4  6638.8  6686.6  7620.246686
# 2018-09-06  1536192000000  6684.4  6702.3  6250.0  6494.8  9576.541423
# 2018-09-07  1536278400000  6494.8  6524.8  6318.8  6397.6  3234.923559
# 2018-09-08  1536364800000  6397.6  6457.7  6073.9  6183.2  3870.776225
# 2018-09-09  1536451200000  6183.2  6459.4  6137.6  6230.9  3636.570370
# 2018-09-10  1536537600000  6230.9  6371.3  6230.9  6304.5  3377.333021
# 2018-09-11  1536624000000  6304.5  6410.9  6162.4  6282.3  3534.805915

# %%
crypto_data_df= historical_prices_df

# %%
return crypto_data_df
